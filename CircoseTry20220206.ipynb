# %% [markdown]
# <a href="https://colab.research.google.com/github/YuehMintTai/000/blob/main/CircoseTry20220206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rpy2
# %load_ext rpy2.ipython
# Out:
# ...
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# install.packages('BioCircos')

# %%
# %%R
# install.packages('statnet')
# install.packages('circlize')
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘DEoptimR’, ‘robustbase’, ‘coda’, ‘trust’, ‘lpSolveAPI’, ‘rle’, ‘tergm’, ‘ergm.count’, ‘sna’, ‘tsna’, ‘ergm’, ‘network’, ‘networkDynamic’, ‘statnet.common’
#
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/DEoptimR_1.0-10.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 36516 bytes (35 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(statnet)
# library(circlize)
# Out:
# R[write to console]: Error in library(statnet) : there is no package called ‘statnet’
# Error in library(statnet) : there is no package called ‘statnet’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
# ...

# %%
# %%R
# # You need devtools for that
# if (!require('devtools')){install.packages('devtools')}
# devtools::install_github('lvulliard/BioCircos.R', build_vignettes = TRUE)
# Out:
# R[write to console]: Downloading GitHub repo lvulliard/BioCircos.R@HEAD
# These packages have more recent versions available.
# It is recommended to update all of them.
# Which would you like to update?
#
# 1: All
# 2: CRAN packages only
# 3: None
# 4: rlang (1.0.0 -> 1.0.1) [CRAN]
#
# Enter one or more numbers, or an empty line to skip updates: 1
# rlang (1.0.0 -> 1.0.1) [CRAN]
# R[write to console]: Installing 1 packages: rlang
#
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/rlang_1.0.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 717371 bytes (700 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(BioCircos)
# BioCircos()

# %%
# %%R
# BioCircos(genome = "hg19", yChr = FALSE, genomeFillColor = "Reds", chrPad = 0,
#   displayGenomeBorder = FALSE, genomeTicksDisplay = FALSE, genomeLabelDy = 0)

# %%
# %%R
# myGenome = list("A" = 10560,"B" = 8808,"C" = 12014,"D" = 7664,"E" = 9403,"F" = 8661)
# G <- BioCircos(genome = myGenome, genomeFillColor = c("tomato2", "darkblue"),genomeTicksScale = 4e+3)
# png('/content/sample_data/000.png')

# %%
# %%R
# print('AAA')
# Out:
# [1] "AAA"

# %%
# %%R
# install.packages('circlize')

# %%
# %%R
# library(circlize)

# %%
# %%R
# set.seed(999)
# n=1000
# df<-data.frame(sectors=sample(letters[1:8],n,replace=TRUE),x=rnorm(n),y=runif(n))

# %%
# %%R
# head(df)
# Out:
#   sectors           x         y
# 1       c -0.33837650 0.2277292
# 2       d  0.20128773 0.8345422
# 3       e  0.60271173 0.6507941
# 4       g -0.22501815 0.8613092
# 5       a -0.01011359 0.3624672
# 6       f -0.19359724 0.5251656

# %%
# %%R
# library(circlize)
# circos.par('track.height'=0.1)
# circos.initialize(df$sectors,x=df$x)

# %%
# %%R
# circos.track(df$sectors, y = df$y,
#     panel.fun = function(x, y) {
#         circos.text(CELL_META$xcenter,
#             CELL_META$cell.ylim[2] + mm_y(5),
#             CELL_META$sector.index)
#         circos.axis(labels.cex = 0.6)
# })
# col = rep(c("#FF0000", "#00FF00"), 4)
# circos.trackPoints(df$sectors, df$x, df$y, col = col, pch = 16, cex = 0.5)
# circos.text(-1, 0.5, "text", sector.index = "a", track.index = 1)

# %%
# %%R
# sectors=c('a','b','c','b','c','a')
# x=1:6
# y=6:1
# plot(y~x)

# %%
# %%R
# circos.track(sectors, x=x, y=y,
#             panel.fun=function(x,y){
#                 circos.points(x,y)
#             }
#             )
# Out:
# R[write to console]: Error in polygon(polar2Cartesian(d2), ...) :
#   plot.new has not been called yet
# Error in polygon(polar2Cartesian(d2), ...) :
#   plot.new has not been called yet
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/rpy2/ipython/rmagic.py in eval(self, code)
#     267                 # Need the newline in case the last line in code is a comment.
# --> 268                 value, visible = ro.r("withVisible({%s\n})" % code)
#     269             except (ri.embedded.RRuntimeError, ValueError) as exception:
#
# /usr/local/lib/python3.7/dist-packages/rpy2/robjects/__init__.py in __call__(self, string)
#     437         p = rinterface.parse(string)
# --> 438         res = self.eval(p)
#     439         return conversion.rpy2py(res)
#
# ...
